# %%
import requests
import json
r = requests.post('https://api.v5.zhelper.net/api/search/',json={'keyword':'电动力学','page':2})
json.loads(r.text)
# Out:
# {'data': [{'title': '经典电动力学',
#    'author': 'John David Jackson; 朱培豫',
#    'publisher': '人民教育出版社',
#    'isbn': None,
#    'extension': 'pdf',
#    'filesize': 13022438,
#    'pages': '517',
#    'year': '1979',
#    'id': 3511906},
#   {'title': '经典电动力学',
#    'author': 'John David Jackson; 朱培豫',
#    'publisher': '人民教育出版社',
#    'isbn': None,
#    'extension': 'pdf',
#    'filesize': 11324651,
#    'pages': '421',
#    'year': '1980',
#    'id': 3511907},
#   {'title': '量子电动力学',
#    'author': '[苏] А.И. 阿希叶泽尔; [苏] В.Б. 别列斯捷茨基(著); 于敏 等(译)',
#    'publisher': '科学出版社',
#    'isbn': None,
#    'extension': 'pdf',
#    'filesize': 31500165,
#    'pages': '630',
#    'year': '1964',
#    'id': 3513999},
#   {'title': '量子电动力学',
#    'author': 'S. N. Gupta; 史天一 等(译)',
#    'publisher': '北京师范大学出版社',
#    'isbn': None,
#    'extension': 'pdf',
#    'filesize': 13603556,
#    'pages': '262',
#    'year': '1981',
#    'id': 3555066},
#   {'title': '量子电动力学讲义',
#    'author': '理查德·费曼,张邦固,朱重远',
#    'publisher': '高等教育出版社',
#    'isbn': '9787040369601',
#    'extension': 'pdf',
#    'filesize': 67084218,
#    'pages': '212',
#    'year': '2013',
#    'id': 5330639},
#   {'title': '量子电动力学',
#    'author': 'S. N. 古普塔; Suraj N. Gupta; 史天一(译); 孙岳(译); 刘在祥(译); 喀兴林(校)',
#    'publisher': '北京师范大学出版社',
#    'isbn': None,
#    'extension': 'pdf',
#    'filesize': 7024837,
#    'pages': '',
#    'year': '1981',
#    'id': 5971536},
#   {'title': '量子电动力学讲义',
#    'author': 'R. P. 费曼; Richard P. Feynman; 张邦固(译); 朱重远(校)',
#    'publisher': '高等教育出版社',
#    'isbn': '9787040369601',
#    'extension': 'pdf',
#    'filesize': 67156808,
#    'pages': '212',
#    'year': '2013',
#    'id': 5971544},
#   {'title': '量子电动力学（第四版）: 理论物理学教程 第四卷',
#    'author': '朗道/Е.М. 栗弗席兹; В.Б. 别列斯捷茨基',
#    'publisher': '高等教育出版社',
#    'isbn': '9787040415971',
#    'extension': 'pdf',
#    'filesize': 12617695,
#    'pages': '625',
#    'year': '2015',
#    'id': 10334384},
#   {'title': '连续介质电动力学（下册）',
#    'author': 'Л. Д. 朗道; Е. М. 栗弗席兹',
#    'publisher': '高等教育出版社',
#    'isbn': '9787040527018',
#    'extension': 'pdf',
#    'filesize': 8817874,
#    'pages': '',
#    'year': '1963',
#    'id': 10341376},
#   {'title': '连续介质电动力学',
#    'author': '朗道 栗弗席兹',
#    'publisher': '高等教育出版社',
#    'isbn': '9787040527018',
#    'extension': 'pdf',
#    'filesize': 107255077,
#    'pages': '595',
#    'year': '2019',
#    'id': 16580274},
#   {'title': '连续媒质电动力学 (上册)',
#    'author': 'Л.Д.朗道 , Е.М.栗弗席兹',
#    'publisher': '人民教育出版社',
#    'isbn': None,
#    'extension': 'pdf',
#    'filesize': 9311063,
#    'pages': '292',
#    'year': '1963',
#    'id': 5414670},
#   {'title': '静电学和电动力学 上册',
#    'author': '〔美〕W .R.斯迈思 著 戴世强 译 W.R.Smythe',
#    'publisher': '科学出版社',
#    'isbn': None,
#    'extension': 'pdf',
#    'filesize': 16347467,
#    'pages': '',
#    'year': '1981',
#    'id': 6015670},
#   {'title': '静电学和电动力学 下册',
#    'author': '〔美〕W .R.斯迈思 著 戴世强 译 W.R.Smythe',
#    'publisher': '科学出版社',
#    'isbn': None,
#    'extension': 'pdf',
#    'filesize': 17871065,
#    'pages': '',
#    'year': '1982',
#    'id': 6015671},
#   {'title': '电磁学与电动力学-上册',
#    'author': '胡友秋',
#    'publisher': '',
#    'isbn': None,
#    'extension': 'pdf',
#    'filesize': 30718446,
#    'pages': '',
#    'year': '',
#    'id': 21138439},
#   {'title': '4-量子电动力学 第四版',
#    'author': '朗道',
#    'publisher': '',
#    'isbn': None,
#    'extension': 'pdf',
#    'filesize': 28940881,
#    'pages': '',
#    'year': '2020',
#    'id': 5498608},
#   {'title': '物理学大题典 电磁学与电动力学',
#    'author': '刘金英',
#    'publisher': '科学出版社',
#    'isbn': None,
#    'extension': 'pdf',
#    'filesize': 14657631,
#    'pages': '497',
#    'year': '',
#    'id': 3516481},
#   {'title': '朗道理论物理学教程 第八卷 连续介质电动力学（第四版）',
#    'author': 'Л. Д. 朗道, Е. М. 栗弗席兹 著,刘寄星,周奇 译',
#    'publisher': '高等教育出版社',
#    'isbn': '9787040527018',
#    'extension': 'pdf',
#    'filesize': 32922868,
#    'pages': '576',
#    'year': '2020',
#    'id': 18063931},
#   {'title': '朗道理论物理学教程 第四卷 量子电动力学(第四版)',
#    'author': 'В. Б. 别列斯捷茨基，Е. М. 栗弗席兹，Л. П. 皮塔耶夫斯基 著,朱允伦 译,庆承瑞 校',
#    'publisher': '高等教育出版社',
#    'isbn': '9787040415971',
#    'extension': 'pdf',
#    'filesize': 23982615,
#    'pages': '',
#    'year': '2015',
#    'id': 18063083},
#   {'title': '物理学大题典2 电磁学与电动力学 第2版',
#    'author': '刘金英，陈银华，张鹏飞',
#    'publisher': '北京：科学出版社',
#    'isbn': None,
#    'extension': 'pdf',
#    'filesize': 68977421,
#    'pages': '492',
#    'year': '2018',
#    'id': 19291575},
#   {'title': 'J.D.杰克逊经典电动力学解题指导 深圳大学学报（增刊）',
#    'author': '奚定平',
#    'publisher': '深圳大学学报编辑部',
#    'isbn': None,
#    'extension': 'pdf',
#    'filesize': 6503584,
#    'pages': '407',
#    'year': '1988',
#    'id': 21895906}],
#  'hits': 47}

# %%
import requests
import json
r = requests.post('https://api.v5.zhelper.net/api/detail/',json={'id':'21895906'})
json.loads(r.text)
# Out:
# {'title': 'J.D.杰克逊经典电动力学解题指导 深圳大学学报（增刊）',
#  'author': '奚定平',
#  'publisher': '深圳大学学报编辑部',
#  'isbn': None,
#  'extension': 'pdf',
#  'filesize': 6503584,
#  'pages': '407',
#  'year': '1988',
#  'description': '',
#  'md5': 'e8fe6cb0bcd91d98b8f34d0d9acdc279',
#  'ipfs_cid': 'bafykbzacec4yvmt5szlf3ocwrc4lz4y57yeny5bweaqbd3pbev6d6276xac4m',
#  'in_libgen': 0,
#  'id': 21895906}
